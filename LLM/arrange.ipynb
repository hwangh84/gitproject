# %% [markdown]
# # NLTK (Natural Language Toolkit) 라이브러리 임포트
# # NLTK는 자연어 처리를 위한 파이썬의 대표적인 라이브러리입니다
# import nltk
#
# # sent_tokenize: 문장 단위로 텍스트를 분리하는 토큰화 도구
# # 마침표, 느낌표, 물음표 등을 기준으로 문장을 구분합니다
# from nltk.tokenize import sent_tokenize
# from nltk.tokenize import word_tokenize
# from nltk.tokenize import WordPunctTokenize
#
# sent_tokenize : 문장 단위
# word_tokenize : 단어 단위
# WordPunctTokenizer: 구두점을 기준으로 토큰화

# %% [markdown]
# # 정규표현식을 사용한 토큰화
# import re
# # findall: 패턴과 일치하는 모든 부분을 찾아 리스트로 반환
# # [abc]: a, b, c 중 하나와 일치하는 문자를 찾음
# re.findall("[abc]","how are you boy")
# # 불용어사전 라이브러리
# from nltk.corpus import stopwords
# # 불용어 사전 등록 언어
# arabic (아랍어)
# azerbaijani (아제르바이잔어)
# danish (덴마크어)
# dutch (네덜란드어)
# english (영어)
# finnish (핀란드어)
# french (프랑스어)
# german (독일어)
# greek (그리스어)
# hungarian (헝가리어)
# indonesian (인도네시아어)
# italian (이탈리아어)
# kazakh (카자흐어)
# nepali (네팔어)
# norwegian (노르웨이어)
# portuguese (포르투갈어)
# romanian (루마니아어)
# russian (러시아어)
# spanish (스페인어)
# swedish (스웨덴어)
# turkish (터키어)
#
# # 다양한 정규표현식 패턴을 사용한 토큰화 예제
#
# # [a-z]{4,}: 소문자로만 이루어진 4글자 이상의 단어 추출
# RegexpTokenizer("[a-z]{4,}")
#
# # [\\w']{3,}: 단어 문자와 아포스트로피를 포함하는 3글자 이상의 단어 추출
# RegexpTokenizer("[\\w']{3,}")
#
# # [\\w]: 단어 문자만 추출 (아포스트로피 제외)
# # 예: can't -> can t로 분리됨
# RegexpTokenizer("[\\w]")
#
# # 어간 추출(Stemming) 예제
# # Porter Stemmer를 사용하여 단어의 어간을 추출
# from nltk.stem import PorterStemmer
# stemmer = PorterStemmer()
#
# # 다양한 형태의 단어에서 어간 추출
# # cooking -> cook
# # cookery -> cookeri -ery 로 끝나는 단어를 처리할 때 y를 i로 변환하는 규칙
# # coobooks -> coobook
# stemmer.stem('cooking'), stemmer.stem('cookery'), stemmer.stem('coobooks')
# # ('cook', 'cookeri', 'coobook')
#
# # 표제어 추출(Lemmatization) 예제
# from nltk.stem import WordNetLemmatizer
# lemmatizer = WordNetLemmatizer()
#
# # pos 매개변수로 품사 지정 (v: 동사)
# print(lemmatizer.lemmatize('cooking', pos='v'))
#
# ## WordCloud (워드 클라우드)
# 텍스트 데이터에서 단어의 빈도를 시각적으로 표현하는 도구입니다.
#
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt
#
# # 워드클라우드 생성 - 주요 키워드 분석 가능
# wordcloud = WordCloud().generate(text)
#
# # 시각화
# plt.figure(figsize=(10, 5))
# plt.imshow(wordcloud)
# plt.axis('off')
# plt.show()

# %% [markdown]
# Bow 모델
#
# Bag-of-Words (BoW) 모델은 자연어 처리(NLP) 분야에서 가장 기본적이고 널리 사용되는 텍스트 표현(Text Representation) 방법론 중 하나
